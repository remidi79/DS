# %% [markdown]
# # Exercice d'entretien - Notation crédit
#
# Parcourez les sections ci-dessous. Vous n'avez pas besoin de tout terminer en 15 minutes. Concentrez-vous sur le raisonnement, la priorisation et les arbitrages.

# %% [markdown]
# ## A. Chargement des données

# %%
import pandas as pd
import numpy as np

DATA_PATH = "data/credit_scoring_interview.csv"
df = pd.read_csv(DATA_PATH, parse_dates=["application_date"])
df.head()

# %% [markdown]
# ## B. EDA rapide
#
# Contrôles suggérés : dimensions, colonnes, équilibre de la cible, résumés numériques, distributions catégorielles.

# %%
# Votre code ici
df.shape

# %% [markdown]
# ## C. Contrôles de qualité des données
#
# Contrôles suggérés : valeurs manquantes, doublons, valeurs impossibles, valeurs aberrantes, période couverte, variables suspectes.

# %%
# Votre code ici

# %% [markdown]
# ## D. Construction de variables
#
# Quelles variables transformer, imputer, capper, encoder ou exclure ?

# %%
# Votre code ici

# %% [markdown]
# ## E. Proposition de modèle
#
# Proposez un modèle de référence et expliquez pourquoi il est adapté.

# %%
# Optionnel : construire un modèle de référence rapide si le temps le permet

# %% [markdown]
# ## F. Évaluation
#
# Quelles métriques utiliseriez-vous ? Pourquoi ? Que signifie un bon seuil pour le métier ?

# %%
# Votre code ici

# %% [markdown]
# ## G. Interprétation métier
#
# Résumez votre recommandation en langage métier.

# %% [markdown]
# - Principaux risques dans les données :
# - Variables à exclure ou à revoir :
# - Métrique recommandée :
# - Approche de production suggérée :
# - Questions ouvertes pour le métier :
